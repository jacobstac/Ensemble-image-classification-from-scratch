# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobstac/Ensemble-Neural-network-for-image-classification/blob/master/topic_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyLDAvis

# %%
# !python3 -m spacy download en

# %%
import nltk; nltk.download('stopwords')

import re
import numpy as np
import pandas as pd
from pprint import pprint

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# for lemmatization, converts to root word, e.g "baking" --> "bake"
import spacy

import pyLDAvis
import pyLDAvis.gensim 
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
